# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# Mlxtend library
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

# pyECLAT library
from pyECLAT import ECLAT

import ast

# %%
clusters = pd.read_csv("Clusters.csv")
baskets = pd.read_csv("customer_basket.csv")

# %%
baskets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89952 entries, 0 to 89951
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   invoice_id     89952 non-null  int64
#  1   list_of_goods  89952 non-null  object
#  2   customer_id    89952 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 2.1+ MB

# %%
baskets["customer_id"].nunique()
# Out:
# 28516

# %%
basket = baskets.merge(clusters, on= "customer_id")

# %%
basket[basket["kmeans_cluster"]== 4]
# Out:
# Empty DataFrame
# Columns: [invoice_id, list_of_goods, customer_id, kmeans_cluster]
# Index: []

# %%
basket_cluster_0 = basket[basket["kmeans_cluster"] == 0]
basket_cluster_1 = basket[basket["kmeans_cluster"] == 1]
basket_cluster_2 = basket[basket["kmeans_cluster"] == 2]
basket_cluster_3 = basket[basket["kmeans_cluster"] == 3]
basket_cluster_4 = basket[basket["kmeans_cluster"] == 4]
basket_cluster_5 = basket[basket["kmeans_cluster"] == 5]
basket_cluster_6 = basket[basket["kmeans_cluster"] == 6]
basket_cluster_7 = basket[basket["kmeans_cluster"] == 7]

# %% [markdown]
# # Cluster 0 (basket analysis)

# %%
baskets_0 = []
for i in range(len(basket_cluster_0)):
    baskets_0.append(ast.literal_eval(basket_cluster_0.iloc[i,1]))

# %%
te = TransactionEncoder()
te_fit = te.fit(baskets_0).transform(baskets_0)
basket_items_0 = pd.DataFrame(te_fit, columns=te.columns_)

# %%
frequent_itemsets_0 = apriori(
    basket_items_0, min_support=0.1, use_colnames=True
    )

rules_0 = association_rules(frequent_itemsets_0, metric="confidence", min_threshold=0.2)

# %%
rules_0.sort_values(by='lift', ascending=False)
# Out:
#                   antecedents                consequents  antecedent support  \
# 41              (cooking oil)          (candy bars, oil)            0.432125
# 36          (candy bars, oil)              (cooking oil)            0.168817
# 30                (cake, oil)              (cooking oil)            0.207592
# 35              (cooking oil)                (cake, oil)            0.432125
# 33                     (cake)         (oil, cooking oil)            0.339005
# 32         (oil, cooking oil)                     (cake)            0.266051
# 39               (candy bars)         (oil, cooking oil)            0.276357
# 38         (oil, cooking oil)               (candy bars)            0.266051
# 34                      (oil)        (cake, cooking oil)            0.455108
# 31        (cake, cooking oil)                      (oil)            0.199251
# 37  (candy bars, cooking oil)                      (oil)            0.162255
# 40                      (oil)  (candy bars, cooking oil)            0.455108
# 17              (cooking oil)                     (gums)            0.432125
# 16                     (gums)              (cooking oil)            0.235617
# 4                      (cake)               (candy bars)            0.339005
# 5                (candy bars)                     (cake)            0.276357
# 7               (cooking oil)                     (cake)            0.432125
# 6                      (cake)              (cooking oil)            0.339005
# 18                  (muffins)              (cooking oil)            0.202069
# 19              (cooking oil)                  (muffins)            0.432125
# 13              (cooking oil)               (candy bars)            0.432125
# 12               (candy bars)              (cooking oil)            0.276357
# 23              (cooking oil)                      (oil)            0.432125
# 22                      (oil)              (cooking oil)            0.455108
# 25                      (oil)                     (gums)            0.455108
# 24                     (gums)                      (oil)            0.235617
# 2               (cooking oil)              (babies food)            0.432125
# 3               (babies food)              (cooking oil)            0.238916
# 10                     (cake)                      (oil)            0.339005
# 11                      (oil)                     (cake)            0.455108
# 28            0.173821  0.104760    0.230187  1.324272  0.025652    1.073219
# 27            0.202069  0.121738    0.267492  1.323769  0.029775    1.089314
# 26            0.455108  0.121738    0.602458  1.323769  0.029775    1.370653
#
#     zhangs_metric
# 41       0.546736
# 36       0.373537
# 30       0.391188
# 35       0.545860
# 33       0.463292
# 32       0.417241
# 39       0.421535
# 38       0.415616
# 34       0.555117
# 31       0.377745
# 37       0.360527
# 40       0.554292
# 17       0.476329
# 16       0.353874
# 4        0.405587
# 5        0.370474
# 7        0.466273
# 6        0.400585
# 18       0.331021
# 19       0.465124
# 13       0.464883
# 12       0.364815
# 23       0.459266
# 22       0.478638
# 25       0.472274
# 24       0.336661
# 2        0.452432
# 3        0.337578
# 10       0.388493
# 11       0.471272
# 15       0.467942
# 14       0.352353
# 21       0.307728
# 20       0.447702
# 9        0.384129
# 8        0.332173
# 1        0.326043
# 0        0.375413
# 29       0.296386
# 28       0.449389
# 27       0.448862
# 26       0.306519

# %% [markdown]
# # Cluster 1 (basket_analysis)

# %%
baskets_1 = []
for i in range(len(basket_cluster_1)):
    baskets_1.append(ast.literal_eval(basket_cluster_1.iloc[i,1]))

# %%
te = TransactionEncoder()
te_fit = te.fit(baskets_1).transform(baskets_1)
basket_items_1 = pd.DataFrame(te_fit, columns=te.columns_)

# %%
frequent_itemsets_1 = apriori(
    basket_items_1, min_support=0.1, use_colnames=True
    )

rules_1 = association_rules(frequent_itemsets_1, metric="confidence", min_threshold=0.2)

# %%
rules_1.sort_values(by='lift', ascending=False)#.head(15)
# Out:
#                   antecedents                consequents  antecedent support  \
# 32         (oil, cooking oil)                     (cake)            0.277017
# 33                     (cake)         (oil, cooking oil)            0.355458
# 30                (cake, oil)              (cooking oil)            0.220203
# 35              (cooking oil)                (cake, oil)            0.452678
# 31        (cake, cooking oil)                      (oil)            0.213153
# 34                      (oil)        (cake, cooking oil)            0.473898
# 41              (cooking oil)          (candy bars, oil)            0.452678
# 36          (candy bars, oil)              (cooking oil)            0.171458
# 39               (candy bars)         (oil, cooking oil)            0.281356
# 38         (oil, cooking oil)               (candy bars)            0.277017
# 16                     (gums)              (cooking oil)            0.240271
# 17              (cooking oil)                     (gums)            0.452678
# 4                      (cake)               (candy bars)            0.355458
# 5                (candy bars)                     (cake)            0.281356
# 20              (cooking oil)                  (napkins)            0.452678
# 21                  (napkins)              (cooking oil)            0.182373
# 37  (candy bars, cooking oil)                      (oil)            0.167322
# 40                      (oil)  (candy bars, cooking oil)            0.473898
# 19              (cooking oil)                  (muffins)            0.452678
# 18                  (muffins)              (cooking oil)            0.210847
# 6                      (cake)              (cooking oil)            0.355458
# 7               (cooking oil)                     (cake)            0.452678
# 2               (cooking oil)              (babies food)            0.452678
# 3               (babies food)              (cooking oil)            0.246305
# 12               (candy bars)              (cooking oil)            0.281356
# 13              (cooking oil)               (candy bars)            0.452678
# 10                     (cake)                      (oil)            0.355458
# 11                      (oil)                     (cake)            0.473898
# 0                      (cake)              (babies food)            0.355458
# 1               (babies food)                     (cake)            0.246305
# 8                      (gums)                     (cake)            0.240271
# 27            0.210847  0.126847    0.267668  1.269487  0.026927    1.077589
# 26            0.473898  0.126847    0.601608  1.269487  0.026927    1.320562
#
#     zhangs_metric
# 32       0.398886
# 33       0.447431
# 30       0.358579
# 35       0.510885
# 31       0.343138
# 34       0.513203
# 41       0.486257
# 36       0.321214
# 39       0.366056
# 38       0.363859
# 16       0.344039
# 17       0.477555
# 4        0.400243
# 5        0.358972
# 20       0.465487
# 21       0.311598
# 37       0.300559
# 40       0.475704
# 19       0.450091
# 18       0.312163
# 6        0.380277
# 7        0.447826
# 2        0.447475
# 3        0.324950
# 12       0.332308
# 13       0.436327
# 10       0.364634
# 11       0.446723
# 0        0.358895
# 1        0.306918
# 8        0.302102
# 9        0.356091
# 23       0.412180
# 22       0.428805
# 15       0.422636
# 14       0.309402
# 29       0.268288
# 28       0.416952
# 25       0.406931
# 24       0.281794
# 27       0.403497
# 26       0.268998

# %% [markdown]
# # Cluster 2 (basket analysis)

# %%
baskets_2 = []
for i in range(len(basket_cluster_2)):
    baskets_2.append(ast.literal_eval(basket_cluster_2.iloc[i,1]))

# %%
te = TransactionEncoder()
te_fit = te.fit(baskets_2).transform(baskets_2)
basket_items_2 = pd.DataFrame(te_fit, columns=te.columns_)

# %%
frequent_itemsets_2 = apriori(
    basket_items_2, min_support=0.05, use_colnames=True
    )

rules_2 = association_rules(frequent_itemsets_2, metric="confidence", min_threshold=0.2)

# %%
rules_2.sort_values(by='lift', ascending=False).head(15)
# Out:
#                     antecedents                 consequents  \
# 114                     (cider)  (dessert wine, white wine)
# 111  (dessert wine, white wine)                     (cider)
# 113              (dessert wine)         (white wine, cider)
# 112         (white wine, cider)              (dessert wine)
# 110       (dessert wine, cider)                (white wine)
# 115                (white wine)       (dessert wine, cider)
# 52               (dessert wine)                     (cider)
# 53                      (cider)              (dessert wine)
# 54                 (white wine)                     (cider)
# 55                      (cider)                (white wine)
# 66               (dessert wine)                (white wine)
# 67                 (white wine)              (dessert wine)
# 22                       (beer)                     (cider)
# 23                      (cider)                      (beer)
# 25                 (white wine)                      (beer)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 114            0.156970            0.086996  0.055746    0.355135  4.082212
# 111            0.086996            0.156970  0.055746    0.640787  4.082212
# 113            0.120047            0.115634  0.055746    0.464366  4.015826
# 112            0.115634            0.120047  0.055746    0.482087  4.015826
# 110            0.065562            0.212896  0.055746    0.850275  3.993845
# 115            0.212896            0.065562  0.055746    0.261844  3.993845
# 52             0.120047            0.156970  0.065562    0.546137  3.479231
# 53             0.156970            0.120047  0.065562    0.417671  3.479231
# 54             0.212896            0.156970  0.115634    0.543147  3.460187
# 55             0.156970            0.212896  0.115634    0.736661  3.460187
# 66             0.120047            0.212896  0.086996    0.724681  3.403917
# 67             0.212896            0.120047  0.086996    0.408629  3.403917
# 22             0.100054            0.156970  0.052053    0.520252  3.314331
# 23             0.156970            0.100054  0.052053    0.331612  3.314331
# 25             0.212896            0.100054  0.070155    0.329526  3.293483
#
#      leverage  conviction  zhangs_metric
# 114  0.042090    1.415807       0.895621
# 111  0.042090    2.346878       0.826978
# 113  0.041864    1.651064       0.853438
# 112  0.041864    1.699037       0.849179
# 110  0.041788    5.256986       0.802209
# 115  0.041788    1.265909       0.952371
# 52   0.046718    1.857452       0.809793
# 53   0.046718    1.511092       0.845261
# 54   0.082216    1.845298       0.903310
# 55   0.082216    2.988936       0.843385
# 66   0.061438    2.858881       0.802566
# 67   0.061438    1.487989       0.897240
# 22   0.036348    1.757234       0.775913
# 23   0.036348    1.346443       0.828298
# 25   0.048854    1.342254       0.884725

# %% [markdown]
# # Cluster 7 (basket analysis)

# %%
baskets_7 = []
for i in range(len(basket_cluster_7)):
    baskets_7.append(ast.literal_eval(basket_cluster_7.iloc[i,1]))

# %%
te = TransactionEncoder()
te_fit = te.fit(baskets_7).transform(baskets_7)
basket_items_7 = pd.DataFrame(te_fit, columns=te.columns_)

# %%
frequent_itemsets_7 = apriori(
    basket_items_7, min_support=0.1, use_colnames=True
    )

rules_7 = association_rules(frequent_itemsets_7, metric="confidence", min_threshold=0.2)

# %%
rules_7.sort_values(by='lift', ascending=False).head(15)
# Out:
#              antecedents           consequents  antecedent support  \
# 31              (salmon)                 (oil)            0.426843
# 30                 (oil)              (salmon)            0.193619
# 56             (catfish)  (fresh tuna, shrimp)            0.243124
# 55  (fresh tuna, shrimp)             (catfish)            0.443344
# 73      (salmon, shrimp)             (seabass)            0.342134
# 77             (seabass)      (salmon, shrimp)            0.287129
# 75     (shrimp, seabass)              (salmon)            0.231023
# 76              (salmon)     (shrimp, seabass)            0.426843
# 16        (french fries)              (shrimp)            0.151815
# 57          (fresh tuna)     (catfish, shrimp)            0.553355
# 54     (catfish, shrimp)          (fresh tuna)            0.201320
# 64  (fresh tuna, shrimp)             (seabass)            0.443344
# 68             (seabass)  (fresh tuna, shrimp)            0.287129
# 66     (shrimp, seabass)          (fresh tuna)            0.231023
# 67          (fresh tuna)     (shrimp, seabass)            0.553355
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 31            0.193619  0.101210    0.237113  1.224637  0.018565    1.057012
# 30            0.426843  0.101210    0.522727  1.224637  0.018565    1.200901
# 56            0.443344  0.124312    0.511312  1.153307  0.016525    1.139082
# 55            0.243124  0.124312    0.280397  1.153307  0.016525    1.051796
# 73            0.287129  0.111111    0.324759  1.131057  0.012875    1.055728
# 77            0.342134  0.111111    0.386973  1.131057  0.012875    1.073144
# 75            0.426843  0.111111    0.480952  1.126767  0.012501    1.104248
# 76            0.231023  0.111111    0.260309  1.126767  0.012501    1.039592
# 16            0.778878  0.133113    0.876812  1.125737  0.014868    1.794991
# 57            0.201320  0.124312    0.224652  1.115895  0.012911    1.030092
# 54            0.553355  0.124312    0.617486  1.115895  0.012911    1.167657
# 64            0.287129  0.141914    0.320099  1.114828  0.014617    1.048493
# 68            0.443344  0.141914    0.494253  1.114828  0.014617    1.100660
# 66            0.553355  0.141914    0.614286  1.110111  0.014076    1.157968
# 67            0.231023  0.141914    0.256461  1.110111  0.014076    1.034212
#
#     zhangs_metric
# 31       0.320037
# 30       0.227475
# 56       0.175628
# 55       0.238798
# 73       0.176132
# 77       0.162541
# 75       0.146305
# 76       0.196290
# 16       0.131685
# 57       0.232530
# 54       0.130037
# 64       0.185035
# 68       0.144488
# 66       0.128988
# 67       0.222076
